# %% [markdown]
# ## 発展問題４：拡張ユークリッドの互除法
#
# **問題**
#
# $a,b$ を入力とし、$ax+by=\gcd(a,b)$ をみたす組（タプル） $(x,y)$ を返り値とする関数 $f(a,b)$ を、以下の説明に沿って再帰関数で実装せよ。（条件をみたす $(x,y)$ は無数にあるが、そのうちの一つを出力する関数ということ。）
#
# **説明**
#
# 以下 $g := \gcd(a,b)$ とおく。拡張ユークリッドの互除法の名前の通り、アイデアはユークリッドの互除法を繰り返していき、停止したところで得られる関係式を逆に戻していく、というものになる。
#
# ここでは、「漸化式そのもの」と「ベースケース」について、考え方のみ以下で提示する。正しく漸化式とベースケースを数学的に導き出すことも課題の一部である。
#
# - $a = qb + r$ とする。$bz+rw = g$ をみたす $(z,w)$ を使って $ax+by = g$ となる $(x,y)$ を見つけることができる。これにより、$f(a,b)$ の計算を $f(b,r)$ の計算に落とすことができる
#
# - ベースケースは $b=0$ のとき。

# %%
## ここに解答を書いてください
