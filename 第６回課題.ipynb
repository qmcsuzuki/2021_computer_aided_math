# %% [markdown]
# # 第６回課題（発展問題）
#
# 正整数 $n$ が与えられたとき、
# $n$ の正の約数をすべて列挙したい。
#
# - 約数列挙を $O(\sqrt{n})$ で実行する関数を実装せよ。
# - とくに $1,5,12,36$ などを試し、約数がもれなくダブリなく列挙できているか確かめよ。
#
# **ヒント：**素数判定のコードを参考にしてください。

# %%
# 解答欄
