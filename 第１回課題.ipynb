# %% [markdown]
# ## 発展問題１
#
# 正整数から正整数への関数 $f$ を
# $$ f(x) = \begin{cases} 3x+1 & \text{$x$: 奇数} \\ x/2 & \text{$x$: 偶数} \end{cases} $$
# と定める。
# コラッツ予想とは、任意の $x$ に対してある非負整数$n$が存在して$f^n(x) = 1$ となる、という予想である。
#
# 小さい数についてコラッツ予想を確かめるべく、以下の問題を解いてください。
#
# - $f^n(x) = 1$ となる最小の非負整数 $n$ を求める関数$g(x)$を書け。
# - $g(27)$ の値を出力せよ
#
# たとえば $g(5)=5$である。
# $f(5) = 16, f(16) = 8, f(8) = 4, f(4) = 2, f(2) = 1$ となる。

# %%
# 解答はここに記入してください。
