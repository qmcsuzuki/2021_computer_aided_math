# %% [markdown]
# # 第５回発展問題（今回は難しいかも）
#
# $N \times N$ の盤のマス目の中央に計 $N$ 個の石を置きたい。ただし、任意の $2$ つの石のチェビシェフ距離が $3$ 以上になるようにしたい。そのような石の置き方の場合の数を $f(N)$ とする。 $f(N)$ を求めるプログラムを書き、 $f(8)$ の値を求めよ。（私の手元のプログラムでは 5 秒程度で実行が完了する。）
#
# なお、座標 $(a,b)$ と $(c,d)$ のチェビシェフ距離は $\max(|a-c|,|b-d|)$ で定義される。
#
# ちなみに手元の計算では、$f(4) = 1$, $f(5) = f(6) = 0$, $f(7) = 758$ である。
#
# ちなみに $N=4$ の場合は、以下のように置くと任意の２点のチェビシェフ距離が $3$ となり、条件をみたす（これが唯一解である）。
#
# ```
# o..o
# ....
# ....
# o..o
# ```

# %%
# 解答欄
