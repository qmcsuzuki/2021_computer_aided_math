# %% [markdown]
# # 第３回課題
#
# リスト $A = [1,3,5,7,9,11]$ がある。
#
# いま、$N_6 := \{0,1,2,3,4,5\}$ の各部分集合 $S$ について、
# $$
# f(S) := \sum_{i \in S} A[i]
# $$
# と定める。
# $$
# \sum_{S \subset N_6} f(S)
# $$
# を求めよ。
#
# この問題は、それぞれの数が何回カウントされるかを考えれば、答えは $2^5 \times \sum_{i}A[i] = 1152$ とわかる。
#
# しかしここでは、以下の方針で $N_6$ の部分集合 $64$ 個それぞれに対して $f(S)$ を計算し、それを足し合わせることで答えを求めよ。
#
# - 集合 $S$ に対応する整数を $s$ とする。$f(S)$ の代わりに $f(s)$ を実装する。
# - $N_6$ の部分集合は整数 $0, \dots, 63$ にそれぞれ対応する。for 文を回して $N_6$ の部分集合すべてを走査する。
# - （このように、部分集合と整数を対応させて for 文で全探索する手法を、俗に bit全探索という）

# %%
## ここに解答を書いてください
