# %% [markdown]
# # 発展問題２
#
# $1234567$ を並べ替えてできる $7$ 桁の整数は $5040$ 個ある。
# そのうち $4321$ の倍数を小さい順にすべて列挙せよ（答えは２つある）。

# %% [markdown]
# ### ヒント（もちろん使わずに解いてもよい）
#
# - たとえば $(6,2,3,5)$ というタプルから数 $6235$ を作るには、
# `6235 = 1000*6 + 100*2 + 10*3 + 1*5` のように計算する方法がある。
# - たとえば `s = "".join("a","b","c")` と書くと文字列が結合され、`s = "abc" となる。`
# - `int("123")` は数 $123$ となる（数字からなる文字列を数に変換したいときは `int()` という関数を使う）

# %%
# ここに解答を書いてください
